# %%
#You can save the output csv straight as as txt file without any errors
import csv
with open('/Users/elena/Desktop/emojional dataset.csv', 'r') as inp, open('/Users/elena/Desktop/new dataset format.csv', 'w') as output:
    writer = csv.writer(output)
    data = []
    yesorno = "True"
    for row1 in csv.reader(inp):
        if row1:
            emoji = row1[0]
            #print(emoji)
            if row1[1]:
                print(emoji)
                data = []
                keyword1 = row1[1]
                data.append(keyword1)
                data.append(emoji)
                #  data.append(yesorno)
                writer.writerow(data)
            if row1[2]:
                data = []
                keyword2 = row1[2]
                data.append(keyword2)
                data.append(emoji)
                #  data.append(yesorno)
                writer.writerow(data)
            if row1[3]:
                data = []
                keyword3 = row1[3]
                data.append(keyword3)
                data.append(emoji)
               # data.append(yesorno)
                writer.writerow(data)
            if row1[4]:
                data = []
                keyword4 = row1[4]
                data.append(keyword4)
                data.append(emoji)
              #  data.append(yesorno)
                writer.writerow(data)
            if row1[5]:
                data = []
                keyword5 = row1[5]
                data.append(keyword5)
                data.append(emoji)
               # data.append(yesorno)
                writer.writerow(data)
            if row1[6]:
                data = []
                keyword6 = row1[6]
                data.append(keyword6)
                data.append(emoji)
               # data.append(yesorno)
                writer.writerow(data)
            if row1[7]:
                data = []
                keyword7 = row1[7]
                data.append(keyword7)
                data.append(emoji)
               # data.append(yesorno)
                writer.writerow(data)
            if row1[8]:
                data = []
                keyword8 = row1[8]
                data.append(keyword8)
                data.append(emoji)
                #data.append(yesorno)
                writer.writerow(data)
            if row1[9]:
                data = []
                keyword9 = row1[9]
                data.append(keyword9)
                data.append(emoji)
              #  data.append(yesorno)
                writer.writerow(data)
            if row1[10]:
                data = []
                keyword10 = row1[10]
                data.append(keyword10)
                data.append(emoji)
               # data.append(yesorno)
                writer.writerow(data)
            if row1[11]:
                data = []
                keyword11 = row1[11]
                data.append(keyword11)
                data.append(emoji)
              #  data.append(yesorno)
                writer.writerow(data)
            if row1[12]:
                data = []
                keyword12 = row1[12]
                data.append(keyword12)
                data.append(emoji)
              #  data.append(yesorno)
                writer.writerow(data)
            if row1[13]:
                data = []
                keyword13 = row1[13]
                data.append(keyword13)
                data.append(emoji)
               # data.append(yesorno)
                writer.writerow(data)
            if row1[14]:
                data = []
                keyword14 = row1[14]
                data.append(keyword14)
                data.append(emoji)
                #data.append(yesorno)
                writer.writerow(data)
            if row1[15]:
                data = []
                keyword15 = row1[15]
                data.append(keyword15)
                data.append(emoji)
                #data.append(yesorno)
                writer.writerow(data)
            if row1[16]:
                data = []
                keyword16 = row1[16]
                data.append(keyword16)
                data.append(emoji)
                #data.append(yesorno)
                writer.writerow(data)
            if row1[17]:
                data = []
                keyword17 = row1[17]
                data.append(keyword17)
                data.append(emoji)
                #data.append(yesorno)
                writer.writerow(data)
            if row1[18]:
                data = []
                keyword18 = row1[18]
                data.append(keyword18)
                data.append(emoji)
                #data.append(yesorno)
                writer.writerow(data)
            if row1[19]:
                data = []
                keyword19 = row1[19]
                data.append(keyword19)
                data.append(emoji)
                #data.append(yesorno)
                writer.writerow(data)
        #    if row1[20]:
        #        data = []
        #        keyword20 = row1[20]
        #        data.append(keyword20)
        #        data.append(emoji)
        #        #data.append(yesorno)
        #        writer.writerow(data)
# Out:
# ﻿😀
# 😃
# 😄
# 😁
# 😆
# 😅
# 🤣
# 😂
# 🙂
# 🙃
# 😉
# 😊
# 😇
# 🥰
# 😍
# 🤩
# 😘
# 😗
# ☺
# 😚
# 😙
# 🥲
# 😋
# 😛
# 😜
# 🤪
# 😝
# 🤑
# 🤗
# 🤭
# 🤫
# 🤔
# 🤐
# 🤨
# 😐
# 😑
# 😶
# 😶‍🌫️
# 😏
# 😒
# 🙄
# 😬
# 😮‍💨
# 🤥
# 😌
# 😔
# 😪
# 🤤
# 😴
# 😷
# 🤒
# 🤕
# 🤢
# 🤮
# 🤧
# 🥵
# 🥶
# 🥴
# 😵
# 😵‍💫
# 🤯
# 🤠
# 🥳
# 🥸
# 😎
# 🤓
# 🧐
# 😕
# 😟
# 🙁
# ☹
# 😮
# 😯
# 😲
# 😳
# 🥺
# 😦
# 😧
# 😨
# 😰
# 😥
# 😢
# 😭
# 😱
# 😖
# 😣
# 😞
# 😓
# 😩
# 😫
# 🥱
# 😤
# 😡
# 😠
# 🤬
# 😈
# 👿
# 💀
# ☠
# 💩
# 🤡
# 👹
# 👺
# 👻
# 👽
# 👾
# 🤖
# 😺
# 😸
# 😹
# 😻
# 😼
# 😽
# 🙀
# 😿
# 😾
# 🙈
# 🙉
# 🙊
# 💋
# 💌
# 💘
# 💝
# 💖
# 💗
# 💓
# 💞
# 💕
# 💟
# ❣
# 💔
# ❤️‍🔥
# ❤️‍🩹
# ❤
# 🧡
# 💛
# 💚
# 💙
# 💜
# 🤎
# 🖤
# 🤍
# 💯
# 💢
# 💥
# 💫
# 💦
# 💨
# 🕳
# 💣
# 💬
# 👁️‍🗨️
# 🗨
# 🗯
# 💭
# 💤
# 👋
# 🤚
# 🖐
# ✋
# 🖖
# 👌
# 🤌
# 🤏
# ✌
# 🤞
# 🤟
# 🤘
# 🤙
# 👈
# 👉
# 👆
# 🖕
# 👇
# ☝
# 👍
# 👎
# ✊
# 👊
# 🤛
# 🤜
# 👏
# 🙌
# 👐
# 🤲
# 🤝
# 🙏
# ✍
# 💅
# 🤳
# 💪
# 🦾
# 🦿
# 🦵
# 🦶
# 👂
# 🦻
# 👃
# 🧠
# 🫀
# 🫁
# 🦷
# 🦴
# 👀
# 👁
# 👅
# 👄
# 👶
# 🧒
# 👦
# 👧
# 🧑
# 👱
# 👨
# 🧔
# 🧔‍♂️
# 🧔‍♀️
# 👨‍🦰
# 👨‍🦱
# 👨‍🦳
# 👨‍🦲
# 👩
# 👩‍🦰
# 🧑‍🦰
# 👩‍🦱
# 🧑‍🦱
# 👩‍🦳
# 🧑‍🦳
# 👩‍🦲
# 🧑‍🦲
# 👱‍♀️
# 👱‍♂️
# 🧓
# 👴
# 👵
# 🙍
# ...

# %%
#shuffle rows 
#https://stackoverflow.com/questions/42438591/shuffle-all-rows-of-a-csv-file-with-python

import random
fid = open("/Users/elena/Desktop/new dataset format.csv", "r")
li = fid.readlines()
fid.close()
print(li)

random.shuffle(li)
print(li)

fid = open("/Users/elena/Desktop/emojional dataset shuffled_example.csv", "w")
fid.writelines(li)
fid.close()
# Out:
# ['happiness,\ufeff😀\n', 'joyful,\ufeff😀\n', 'excited,\ufeff😀\n', 'cheer,\ufeff😀\n', 'pleasure,\ufeff😀\n', 'happiness,😃\n', 'amusement,😃\n', 'excited,😃\n', 'pleasantly surprised,😃\n', 'adoring,😃\n', 'happiness,😄\n', 'laughter,😄\n', 'amusement,😄\n', 'appreciation,😄\n', 'happiness,😁\n', 'laughing,😁\n', 'silly,😁\n', 'amused,😁\n', 'proud,😁\n', 'gratified,😁\n', 'achievements,😁\n', 'laughter,😆\n', 'evil laughter,😆\n', 'excitement,😆\n', 'ridiculous,😆\n', 'really funny,😆\n', 'laughter,😅\n', 'nerves,😅\n', 'sweat,😅\n', 'discomfort,😅\n', 'relief,😅\n', 'difficult task,😅\n', 'frightened unexpectedly,😅\n', 'laughing,🤣\n', 'hysterical,🤣\n', 'ridiculous,🤣\n', 'extremely funny,🤣\n', 'laughing,😂\n', 'really funny,😂\n', 'adorably funny,😂\n', 'relief,😂\n', 'happiness,🙂\n', 'patronizing,🙂\n', 'ironic,🙂\n', 'passive aggressive,🙂\n', 'positive,🙂\n', 'indifferent,🙂\n', 'caring,🙂\n', 'sarcastic,🙂\n', 'irony,🙃\n', 'sarcasm,🙃\n', 'joking,🙃\n', 'goofiness,🙃\n', 'silliness,🙃\n', 'bemused,🙃\n', 'not serious,🙃\n', 
# ...
